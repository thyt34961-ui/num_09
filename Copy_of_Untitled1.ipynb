# %% [markdown]
# <a href="https://colab.research.google.com/github/thyt34961-ui/num_09/blob/main/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===============================
# Example: Singly Linked List using Excel Data
# ===============================

import pandas as pd

# Step 1: Read the Excel file
file_path = "/content/sample_data/Customer-Purchase-History.xlsx"
df = pd.read_excel(file_path)

# Step 2: Show the first few rows
print("=== Data Preview (head) ===")
print(df.head(), "\n")

# Let's assume your dataset has columns like:
# Student_ID | Name | Score
# If your column names are different, update below
cols = list(df.columns)
print("Detected Columns:", cols, "\n")

# Step 3: Define the Node and Linked List classes
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        """Add new node to the end of the list"""
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node

    def print_list(self):
        """Print all nodes in the linked list"""
        current = self.head
        print("=== Singly Linked List Data ===")
        while current:
            print(current.data)
            current = current.next
        print()

# Step 4: Convert Excel data rows into Python dictionaries
records = df.to_dict(orient="records")

# Step 5: Create a Singly Linked List and add each record
linked_list = SinglyLinkedList()
for record in records:
    linked_list.append(record)

# Step 6: Display the linked list
linked_list.print_list()

# %%
# ====================================
# Example: Doubly Linked List using Excel Data
# ====================================

import pandas as pd

# Step 1: Read the Excel file
file_path = "/content/sample_data/Customer-Purchase-History.xlsx"
df = pd.read_excel(file_path)

# Step 2: Show the first few rows
print("=== Data Preview (head) ===")
print(df.head(), "\n")

# Step 3: Check column names
cols = list(df.columns)
print("Detected Columns:", cols, "\n")

# Step 4: Define Node and Doubly Linked List
class DNode:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        """Add new node to the end"""
        new_node = DNode(data)
        if not self.head:
            self.head = new_node
            return
        cur = self.head
        while cur.next:
            cur = cur.next
        cur.next = new_node
        new_node.prev = cur

    def print_forward(self):
        """Traverse forward"""
        cur = self.head
        print("=== Doubly Linked List (Forward Traversal) ===")
        while cur:
            print(cur.data)
            cur = cur.next
        print()

    def print_backward(self):
        """Traverse backward"""
        cur = self.head
        if not cur:
            print("List is empty")
            return
        # Move to the last node
        while cur.next:
            cur = cur.next
        print("=== Doubly Linked List (Backward Traversal) ===")
        while cur:
            print(cur.data)
            cur = cur.prev
        print()

# Step 5: Convert Excel rows to dictionaries
records = df.to_dict(orient="records")

# Step 6: Create and fill the Doubly Linked List
dll = DoublyLinkedList()
for record in records:
    dll.append(record)

# Step 7: Show results
dll.print_forward()
dll.print_backward()
# Out:
# === Data Preview (head) ===
#   CustomerID  Product PurchaseDate  Quantity  UnitPrice    CustomerName  \
# 0      C5361    Phone   2024-03-05         8     618.83  Customer C5361
# 1      C6231   Laptop   2025-06-21         7     366.22  Customer C6231
# 2      C7704    Chair   2023-06-25         5     634.51  Customer C7704
# 3      C2923  Printer   2023-09-30         3     508.63  Customer C2923
# 4      C4847  Monitor   2023-04-03         4     452.06  Customer C4847
#
#    ProductCategory PaymentMethod  ReviewRating  TotalPrice
# 0  Office Supplies          Cash             1     4950.64
# 1      Electronics    Debit Card             3     2563.54
# 2  Office Supplies   Credit Card             4     3172.55
# 3  Office Supplies     Gift Card             1     1525.89
# 4      Electronics   Credit Card             2     1808.24
#
# ...

# %%
import pandas as pd

# Step 1: Load the dataset
df = pd.read_excel("/content/sample_data/Customer-Purchase-History.xlsx")

# Step 2: Show first few rows
print("📘 Data Preview:")
print(df.head(), "\n")

# Step 3: Convert first column to a list (e.g., student IDs or Names)
students = df.iloc[:, 0].tolist()  # You can replace with df['Name'].tolist() if column exists
print("🎯 Sample Students List:")
print(students[:10], "\n")

# Step 4: Define Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# Step 5: Define Circular Linked List class
class CircularLinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            self.head.next = self.head
        else:
            temp = self.head
            while temp.next != self.head:
                temp = temp.next
            temp.next = new_node
            new_node.next = self.head

    def display(self):
        nodes = []
        if not self.head:
            return nodes
        temp = self.head
        while True:
            nodes.append(temp.data)
            temp = temp.next
            if temp == self.head:
                break
        return nodes

    def delete(self, key):
        if not self.head:
            return
        curr = self.head
        prev = None

        # Case 1: Head node deletion
        if curr.data == key:
            while curr.next != self.head:
                curr = curr.next
            curr.next = self.head.next
            self.head = self.head.next
            return

        # Case 2: Delete non-head node
        curr = self.head
        while curr.next != self.head:
            prev = curr
            curr = curr.next
            if curr.data == key:
                prev.next = curr.next
                return

# Step 6: Create and display Circular Linked List
cll = CircularLinkedList()
for student in students[:10]:  # limit for clarity
    cll.append(student)

# Step 7: Display the list
print("🔁 Circular Linked List (First 10 Students):")
print(" -> ".join(map(str, cll.display())), "\n")

# Step 8: Delete one element
if students:
    to_delete = students[3]  # Delete 4th student
    cll.delete(to_delete)
    print(f"🗑 After deleting '{to_delete}':")
    print(" -> ".join(map(str, cll.display())))
# Out:
# 📘 Data Preview:
#   CustomerID  Product PurchaseDate  Quantity  UnitPrice    CustomerName  \
# 0      C5361    Phone   2024-03-05         8     618.83  Customer C5361
# 1      C6231   Laptop   2025-06-21         7     366.22  Customer C6231
# 2      C7704    Chair   2023-06-25         5     634.51  Customer C7704
# 3      C2923  Printer   2023-09-30         3     508.63  Customer C2923
# 4      C4847  Monitor   2023-04-03         4     452.06  Customer C4847
#
#    ProductCategory PaymentMethod  ReviewRating  TotalPrice
# 0  Office Supplies          Cash             1     4950.64
# 1      Electronics    Debit Card             3     2563.54
# 2  Office Supplies   Credit Card             4     3172.55
# 3  Office Supplies     Gift Card             1     1525.89
# 4      Electronics   Credit Card             2     1808.24
#
# 🎯 Sample Students List:
# ['C5361', 'C6231', 'C7704', 'C2923', 'C4847', 'C7317', 'C5076', 'C5181', 'C9564', 'C7521']
#
# ...
